# %%
# install the packages we need

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load the data

NBA19 = pd.read_excel("Assignment Data/NBA2019odds.xlsx")
NBA19
# Out:
#                        team               opponent  day  month  year  winodds  \
# 0     Golden State Warriors        Houston Rockets    4      1  2019     1.27
# 1           Houston Rockets  Golden State Warriors    4      1  2019     3.92
# 2           New York Knicks     Washington Wizards   17      1  2019     3.52
# 3        Washington Wizards        New York Knicks   17      1  2019     1.32
# 4            Boston Celtics     Los Angeles Lakers    8      2  2019     1.24
# ...                     ...                    ...  ...    ...   ...      ...
# 2455  Golden State Warriors      Charlotte Hornets    1      4  2019     1.13
# 2456       Dallas Mavericks              Utah Jazz   15     11  2018     2.75
# 2457              Utah Jazz       Dallas Mavericks   15     11  2018     1.47
# 2458         Boston Celtics          Chicago Bulls    9     12  2018     1.28
# 2459          Chicago Bulls         Boston Celtics    9     12  2018     3.80
#
# ...

# %%
NBA19['winprob']= 1/(NBA19['winodds'])/(1/(NBA19['winodds'])+ 1/(NBA19['loseodds']))
NBA19
# Out:
#                        team               opponent  day  month  year  winodds  \
# 0     Golden State Warriors        Houston Rockets    4      1  2019     1.27
# 1           Houston Rockets  Golden State Warriors    4      1  2019     3.92
# 2           New York Knicks     Washington Wizards   17      1  2019     3.52
# 3        Washington Wizards        New York Knicks   17      1  2019     1.32
# 4            Boston Celtics     Los Angeles Lakers    8      2  2019     1.24
# ...                     ...                    ...  ...    ...   ...      ...
# 2455  Golden State Warriors      Charlotte Hornets    1      4  2019     1.13
# 2456       Dallas Mavericks              Utah Jazz   15     11  2018     2.75
# 2457              Utah Jazz       Dallas Mavericks   15     11  2018     1.47
# 2458         Boston Celtics          Chicago Bulls    9     12  2018     1.28
# 2459          Chicago Bulls         Boston Celtics    9     12  2018     3.80
#
# ...

# %%
NBAteamprobs=NBA19.groupby('team')[['winprob','win']].mean()
NBAteamprobs
# Out:
#                          winprob       win
# team
# Atlanta Hawks           0.313679  0.353659
# Boston Celtics          0.634365  0.597561
# Brooklyn Nets           0.445081  0.512195
# Charlotte Hornets       0.492572  0.475610
# Chicago Bulls           0.307335  0.268293
# Cleveland Cavaliers     0.257142  0.231707
# Dallas Mavericks        0.427560  0.402439
# Denver Nuggets          0.615707  0.658537
# Detroit Pistons         0.496879  0.500000
# Golden State Warriors   0.739907  0.695122
# Houston Rockets         0.633199  0.646341
# Indiana Pacers          0.554326  0.585366
# Los Angeles Clippers    0.519075  0.585366
# Los Angeles Lakers      0.474280  0.451220
# Memphis Grizzlies       0.409253  0.402439
# Miami Heat              0.496047  0.475610
# Milwaukee Bucks         0.689646  0.731707
# Minnesota Timberwolves  0.463423  0.439024
# New Orleans Pelicans    0.456446  0.402439
# New York Knicks         0.273845  0.207317
# Oklahoma City Thunder   0.624037  0.597561
# ...

# %%
sns.relplot(x="winprob", y="win", data = NBAteamprobs, s=30)

# %%
NBA19 = NBA19[NBA19['home'] == 1].reset_index(drop=True)
NBA19
# Out:
#                        team                opponent  day  month  year  \
# 0     Golden State Warriors         Houston Rockets    4      1  2019
# 1        Washington Wizards         New York Knicks   17      1  2019
# 2            Boston Celtics      Los Angeles Lakers    8      2  2019
# 3          Dallas Mavericks  Portland Trail Blazers   10      2  2019
# 4         Memphis Grizzlies       San Antonio Spurs   13      2  2019
# ...                     ...                     ...  ...    ...   ...
# 1225        Milwaukee Bucks  Portland Trail Blazers   22     11  2018
# 1226         Denver Nuggets           Atlanta Hawks   16     11  2018
# 1227  Golden State Warriors       Charlotte Hornets    1      4  2019
# 1228       Dallas Mavericks               Utah Jazz   15     11  2018
# 1229          Chicago Bulls          Boston Celtics    9     12  2018
#
#       winodds  loseodds  teampts  oppopts  diff  overtime  home  \
# ...

# %%
pd_lt9 = NBA19[NBA19['diff'] < 9].reset_index(drop=True)
pd_lt9pd_lt9
# Out:
#                        team                opponent  day  month  year  \
# 0     Golden State Warriors         Houston Rockets    4      1  2019
# 1        Washington Wizards         New York Knicks   17      1  2019
# 2            Boston Celtics      Los Angeles Lakers    8      2  2019
# 3          Dallas Mavericks  Portland Trail Blazers   10      2  2019
# 4         Memphis Grizzlies       San Antonio Spurs   13      2  2019
# ..                      ...                     ...  ...    ...   ...
# 552         New York Knicks           Brooklyn Nets    9     12  2018
# 553      Philadelphia 76ers       Memphis Grizzlies    3     12  2018
# 554            Phoenix Suns  Minnesota Timberwolves   16     12  2018
# 555  Portland Trail Blazers  Minnesota Timberwolves    9     12  2018
# 556       San Antonio Spurs          Denver Nuggets   27     12  2018
#
#      winodds  loseodds  teampts  oppopts  diff  overtime  home  \
# ...

# %%
pd_gt9 = NBA19[NBA19['diff'] > 9].reset_index(drop=True)
pd_gt9
# Out:
#                       team                opponent  day  month  year  winodds  \
# 0            Brooklyn Nets         New York Knicks   26      1  2019     1.22
# 1         Dallas Mavericks      Los Angeles Lakers    8      1  2019     1.32
# 2         Dallas Mavericks            Phoenix Suns   10      1  2019     1.15
# 3          Detroit Pistons         Milwaukee Bucks   30      1  2019     3.45
# 4     Los Angeles Clippers           Orlando Magic    6      1  2019     1.36
# ..                     ...                     ...  ...    ...   ...      ...
# 591        Milwaukee Bucks  Portland Trail Blazers   22     11  2018     1.33
# 592         Denver Nuggets           Atlanta Hawks   16     11  2018     1.08
# 593  Golden State Warriors       Charlotte Hornets    1      4  2019     1.13
# 594       Dallas Mavericks               Utah Jazz   15     11  2018     2.75
# 595          Chicago Bulls          Boston Celtics    9     12  2018     3.80
#
# ...

# %%
overtime = NBA19[NBA19['overtime'] == 1].reset_index(drop=True)
overtime
# Out:
#                      team            opponent  day  month  year  winodds  \
# 0   Golden State Warriors     Houston Rockets    4      1  2019     1.27
# 1   Oklahoma City Thunder           Utah Jazz   23      2  2019     1.56
# 2        Sacramento Kings     Milwaukee Bucks   28      2  2019     3.18
# 3           Atlanta Hawks     Milwaukee Bucks   31      3  2019     2.19
# 4       Memphis Grizzlies     Houston Rockets   21      3  2019     2.89
# ..                    ...                 ...  ...    ...   ...      ...
# 62        Toronto Raptors          Miami Heat    7      4  2019     1.42
# 63    Cleveland Cavaliers       Brooklyn Nets   14      2  2019     3.61
# 64      Charlotte Hornets   San Antonio Spurs   27      3  2019     2.58
# 65  Oklahoma City Thunder     Toronto Raptors   21      3  2019     1.49
# 66  Oklahoma City Thunder  Los Angeles Lakers   18      1  2019     1.19
#
#     loseodds  teampts  oppopts  diff  overtime  home  \
# ...

# %%
regulartime = NBA19[NBA19['overtime'] == 0].reset_index(drop=True)
regulartime
# Out:
#                        team                opponent  day  month  year  \
# 0        Washington Wizards         New York Knicks   17      1  2019
# 1            Boston Celtics      Los Angeles Lakers    8      2  2019
# 2          Dallas Mavericks  Portland Trail Blazers   10      2  2019
# 3         Memphis Grizzlies       San Antonio Spurs   13      2  2019
# 4                Miami Heat   Golden State Warriors   28      2  2019
# ...                     ...                     ...  ...    ...   ...
# 1158        Milwaukee Bucks  Portland Trail Blazers   22     11  2018
# 1159         Denver Nuggets           Atlanta Hawks   16     11  2018
# 1160  Golden State Warriors       Charlotte Hornets    1      4  2019
# 1161       Dallas Mavericks               Utah Jazz   15     11  2018
# 1162          Chicago Bulls          Boston Celtics    9     12  2018
#
#       winodds  loseodds  teampts  oppopts  diff  overtime  home  \
# ...

# %%
games_2018 = NBA19[NBA19['year'] == 2018].reset_index(drop=True)
games_2018
# Out:
#                    team                opponent  day  month  year  winodds  \
# 0     Charlotte Hornets         Milwaukee Bucks   18     10  2018     2.37
# 1       Detroit Pistons      Philadelphia 76ers   24     10  2018     1.96
# 2    Los Angeles Lakers       San Antonio Spurs   23     10  2018     1.85
# 3            Miami Heat       Charlotte Hornets   21     10  2018     1.61
# 4    Philadelphia 76ers           Orlando Magic   21     10  2018     1.07
# ..                  ...                     ...  ...    ...   ...      ...
# 537       Orlando Magic       San Antonio Spurs   20     12  2018     2.33
# 538     Milwaukee Bucks  Portland Trail Blazers   22     11  2018     1.33
# 539      Denver Nuggets           Atlanta Hawks   16     11  2018     1.08
# 540    Dallas Mavericks               Utah Jazz   15     11  2018     2.75
# 541       Chicago Bulls          Boston Celtics    9     12  2018     3.80
#
#      loseodds  teampts  oppopts  diff  overtime  home  \
# ...

# %%
games_2019 = NBA19[NBA19['year'] == 2019].reset_index(drop=True)
games_2019
# Out:
#                       team                opponent  day  month  year  winodds  \
# 0    Golden State Warriors         Houston Rockets    4      1  2019     1.27
# 1       Washington Wizards         New York Knicks   17      1  2019     1.32
# 2           Boston Celtics      Los Angeles Lakers    8      2  2019     1.24
# 3         Dallas Mavericks  Portland Trail Blazers   10      2  2019     2.30
# 4        Memphis Grizzlies       San Antonio Spurs   13      2  2019     3.57
# ..                     ...                     ...  ...    ...   ...      ...
# 683  Golden State Warriors       San Antonio Spurs    7      2  2019     1.05
# 684          Brooklyn Nets        Dallas Mavericks    5      3  2019     1.43
# 685     Philadelphia 76ers  Minnesota Timberwolves   16      1  2019     1.41
# 686         Indiana Pacers      Los Angeles Lakers    6      2  2019     2.17
# 687  Golden State Warriors       Charlotte Hornets    1      4  2019     1.13
#
# ...

# %%
october = NBA19[NBA19['month'] == 10].reset_index(drop=True)
october
# Out:
#                        team               opponent  day  month  year  winodds  \
# 0         Charlotte Hornets        Milwaukee Bucks   18     10  2018     2.37
# 1           Detroit Pistons     Philadelphia 76ers   24     10  2018     1.96
# 2        Los Angeles Lakers      San Antonio Spurs   23     10  2018     1.85
# 3                Miami Heat      Charlotte Hornets   21     10  2018     1.61
# 4        Philadelphia 76ers          Orlando Magic   21     10  2018     1.07
# ..                      ...                    ...  ...    ...   ...      ...
# 98          New York Knicks  Golden State Warriors   27     10  2018     7.59
# 99        Charlotte Hornets          Chicago Bulls   27     10  2018     1.17
# 100  Minnesota Timberwolves        Milwaukee Bucks   27     10  2018     2.15
# 101    Los Angeles Clippers     Washington Wizards   29     10  2018     1.60
# 102           Orlando Magic      Charlotte Hornets   20     10  2018     2.03
#
# ...

# %%
november = NBA19[NBA19['month'] == 11].reset_index(drop=True)
november
# Out:
#                        team                opponent  day  month  year  \
# 0             Atlanta Hawks       Charlotte Hornets   26     11  2018
# 1             Brooklyn Nets         Detroit Pistons    1     11  2018
# 2             Chicago Bulls          Denver Nuggets    1     11  2018
# 3             Chicago Bulls     Cleveland Cavaliers   11     11  2018
# 4             Chicago Bulls       San Antonio Spurs   27     11  2018
# ..                      ...                     ...  ...    ...   ...
# 210           Chicago Bulls         Toronto Raptors   18     11  2018
# 211  Minnesota Timberwolves       San Antonio Spurs   29     11  2018
# 212         Milwaukee Bucks  Portland Trail Blazers   22     11  2018
# 213          Denver Nuggets           Atlanta Hawks   16     11  2018
# 214        Dallas Mavericks               Utah Jazz   15     11  2018
#
#      winodds  loseodds  teampts  oppopts  diff  overtime  home  \
# ...

# %%
december = NBA19[NBA19['month'] == 12].reset_index(drop=True)
december
# Out:
#                        team                opponent  day  month  year  \
# 0             Brooklyn Nets         Toronto Raptors    8     12  2018
# 1         Charlotte Hornets         Detroit Pistons   13     12  2018
# 2     Golden State Warriors  Portland Trail Blazers   28     12  2018
# 3            Indiana Pacers     Cleveland Cavaliers   19     12  2018
# 4    Portland Trail Blazers          Denver Nuggets    1     12  2018
# ..                      ...                     ...  ...    ...   ...
# 219               Utah Jazz       San Antonio Spurs    5     12  2018
# 220          Indiana Pacers         Detroit Pistons   29     12  2018
# 221       San Antonio Spurs    Los Angeles Clippers   14     12  2018
# 222           Orlando Magic       San Antonio Spurs   20     12  2018
# 223           Chicago Bulls          Boston Celtics    9     12  2018
#
#      winodds  loseodds  teampts  oppopts  diff  overtime  home  \
# ...

# %%
january = NBA19[NBA19['month'] == 1].reset_index(drop=True)
january
# Out:
#                        team                opponent  day  month  year  \
# 0     Golden State Warriors         Houston Rockets    4      1  2019
# 1        Washington Wizards         New York Knicks   17      1  2019
# 2           Detroit Pistons        Sacramento Kings   20      1  2019
# 3           Houston Rockets         Toronto Raptors   26      1  2019
# 4    Minnesota Timberwolves            Phoenix Suns   21      1  2019
# ..                      ...                     ...  ...    ...   ...
# 216          Denver Nuggets            Phoenix Suns   26      1  2019
# 217   Golden State Warriors           Chicago Bulls   12      1  2019
# 218       Charlotte Hornets        Dallas Mavericks    3      1  2019
# 219         Milwaukee Bucks              Miami Heat   16      1  2019
# 220      Philadelphia 76ers  Minnesota Timberwolves   16      1  2019
#
#      winodds  loseodds  teampts  oppopts  diff  overtime  home  \
# ...

# %%
feb = NBA19[NBA19['month'] == 2].reset_index(drop=True)
feb
# Out:
#                       team                opponent  day  month  year  winodds  \
# 0           Boston Celtics      Los Angeles Lakers    8      2  2019     1.24
# 1         Dallas Mavericks  Portland Trail Blazers   10      2  2019     2.30
# 2        Memphis Grizzlies       San Antonio Spurs   13      2  2019     3.57
# 3               Miami Heat   Golden State Warriors   28      2  2019     4.90
# 4          Milwaukee Bucks          Boston Celtics   22      2  2019     1.38
# ..                     ...                     ...  ...    ...   ...      ...
# 153              Utah Jazz            Phoenix Suns    7      2  2019     1.06
# 154   New Orleans Pelicans           Orlando Magic   13      2  2019     1.51
# 155          Orlando Magic       Charlotte Hornets   15      2  2019     1.57
# 156  Golden State Warriors       San Antonio Spurs    7      2  2019     1.05
# 157         Indiana Pacers      Los Angeles Lakers    6      2  2019     2.17
#
# ...

# %%
march = NBA19[NBA19['month'] == 3].reset_index(drop=True)
march
# Out:
#                       team            opponent  day  month  year  winodds  \
# 0            Atlanta Hawks     Milwaukee Bucks   31      3  2019     2.19
# 1        Charlotte Hornets  Washington Wizards    9      3  2019     1.55
# 2            Chicago Bulls  Philadelphia 76ers    7      3  2019     2.49
# 3         Dallas Mavericks     Houston Rockets   11      3  2019     4.18
# 4           Denver Nuggets    Dallas Mavericks   15      3  2019     1.13
# ..                     ...                 ...  ...    ...   ...      ...
# 220  Golden State Warriors    Dallas Mavericks   24      3  2019     1.08
# 221    Cleveland Cavaliers     Detroit Pistons    2      3  2019     3.85
# 222         Indiana Pacers      Denver Nuggets   24      3  2019     2.03
# 223        Toronto Raptors     New York Knicks   19      3  2019     1.11
# 224          Brooklyn Nets    Dallas Mavericks    5      3  2019     1.43
#
#      loseodds  teampts  oppopts  diff  overtime  home  \
# ...

# %%
april = NBA19[NBA19['month'] == 4].reset_index(drop=True)
april
# Out:
#                      team                opponent  day  month  year  winodds  \
# 0           Atlanta Hawks          Indiana Pacers   11      4  2019     1.45
# 1   Oklahoma City Thunder         Houston Rockets   10      4  2019     2.28
# 2      Washington Wizards           Chicago Bulls    4      4  2019     1.19
# 3       Charlotte Hornets         Toronto Raptors    6      4  2019     3.05
# 4        Dallas Mavericks  Minnesota Timberwolves    4      4  2019     1.74
# ..                    ...                     ...  ...    ...   ...      ...
# 79   New Orleans Pelicans      Los Angeles Lakers    1      4  2019     1.65
# 80   Los Angeles Clippers         Houston Rockets    4      4  2019     2.21
# 81        Houston Rockets            Phoenix Suns    8      4  2019     1.02
# 82          Orlando Magic           Atlanta Hawks    6      4  2019     1.24
# 83  Golden State Warriors       Charlotte Hornets    1      4  2019     1.13
#
# ...

# %%
np.corrcoef(NBAteamprobs["winprob"], NBAteamprobs['win'])
# Out:
# array([[1.        , 0.95700262],
#        [0.95700262, 1.        ]])

# %%
np.corrcoef(NBA19["winprob"], NBA19['win'])
# Out:
# array([[1.        , 0.39652887],
#        [0.39652887, 1.        ]])

# %%
np.corrcoef(pd_lt9["winprob"], pd_lt9['win'])
# Out:
# array([[1.        , 0.19811648],
#        [0.19811648, 1.        ]])

# %%
np.corrcoef(pd_gt9["winprob"], pd_gt9['win'])
# Out:
# array([[1.        , 0.57647206],
#        [0.57647206, 1.        ]])

# %%
np.corrcoef(overtime["winprob"], overtime['win'])
# Out:
# array([[1.        , 0.03225853],
#        [0.03225853, 1.        ]])

# %%
np.corrcoef(regulartime["winprob"], regulartime['win'])
# Out:
# array([[1.       , 0.4144347],
#        [0.4144347, 1.       ]])

# %%
np.corrcoef(games_2018["winprob"], games_2018['win'])
# Out:
# array([[1.        , 0.33824657],
#        [0.33824657, 1.        ]])

# %%
np.corrcoef(games_2019["winprob"], games_2019['win'])
# Out:
# array([[1.        , 0.43797601],
#        [0.43797601, 1.        ]])

# %%
print(np.corrcoef(october["winprob"], october['win']))
# Out:
# [[1.        0.4132173]
#  [0.4132173 1.       ]]

# %%
print(np.corrcoef(november["winprob"], november['win']))
# Out:
# [[1.         0.31889017]
#  [0.31889017 1.        ]]

# %%
print(np.corrcoef(january["winprob"], january['win']))
# Out:
# [[1.        0.5035297]
#  [0.5035297 1.       ]]

# %%
print(np.corrcoef(december["winprob"], december['win']))
# Out:
# [[1.         0.32183843]
#  [0.32183843 1.        ]]

# %%
print(np.corrcoef(april["winprob"], april['win']))
# Out:
# [[1.        0.4554355]
#  [0.4554355 1.       ]]

# %%
print(np.corrcoef(feb["winprob"], feb['win']))
# Out:
# [[1.         0.37928007]
#  [0.37928007 1.        ]]

# %%
print(np.corrcoef(march["winprob"], march['win']))
# Out:
# [[1.         0.41270836]
#  [0.41270836 1.        ]]
