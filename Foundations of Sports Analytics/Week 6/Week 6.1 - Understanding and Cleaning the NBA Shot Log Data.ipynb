# %% [markdown]
# ### We will use the 2016-2017 basketball shot log data to demonstrate how to test the hot hand.
#
# #### Import useful libraries and the shot log data

# %% [markdown]
# #### Please note that the 3 lecture notebooks for this week must be run in order, as the following notebooks rely on the output of the previous

# %%
import pandas as pd
import numpy as np

Shotlog=pd.read_csv("../../Data/Week 6/Shotlog_16_17.csv")
Shotlog.head()
# Out:
#   team_previous_shot player_position home_game  location_x  \
# 0                NaN              SF       Yes        97.0
# 1             MISSED               C       Yes        52.0
# 2             SCORED              SG       Yes       239.0
# 3             SCORED              PG       Yes       102.0
# 4             SCORED              PF       Yes       128.0
#
#   opponent_previous_shot home_team             shot_type  points away_team  \
# 0                 SCORED       ATL      Pullup Jump Shot       2       WAS
# 1                 SCORED       ATL         Tip Dunk Shot       2       WAS
# 2                 MISSED       ATL             Jump Shot       2       WAS
# 3                 SCORED       ATL      Pullup Jump Shot       2       WAS
# 4                 MISSED       ATL  Turnaround Jump Shot       2       WAS
#
#    location_y  time        date     shoot_player  time_from_last_shot  \
# 0       405.0  1:09  10/27/2016    Kent Bazemore                  NaN
# 1       250.0  1:11  10/27/2016    Dwight Howard                  2.0
# 2       223.0  1:41  10/27/2016      Kyle Korver                 30.0
# 3       385.0  2:16  10/27/2016  Dennis Schroder                 35.0
# 4       265.0  2:40  10/27/2016     Paul Millsap                 24.0
#
#    quarter current_shot_outcome
# 0        1               MISSED
# 1        1               SCORED
# 2        1               SCORED
# 3        1               SCORED
# 4        1               MISSED

# %%
Shotlog.shape
# Out:
# (210072, 16)

# %% [markdown]
# ## Data Preparation
#
# ### Missing Value

# %%
Shotlog.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210072 entries, 0 to 210071
# Data columns (total 16 columns):
# team_previous_shot        207612 non-null object
# player_position           210072 non-null object
# home_game                 210072 non-null object
# location_x                209675 non-null float64
# opponent_previous_shot    208462 non-null object
# home_team                 210072 non-null object
# shot_type                 210072 non-null object
# points                    210072 non-null int64
# away_team                 210072 non-null object
# location_y                209675 non-null float64
# time                      210072 non-null object
# date                      210072 non-null object
# shoot_player              210072 non-null object
# time_from_last_shot       200072 non-null float64
# quarter                   210072 non-null int64
# current_shot_outcome      210072 non-null object
# dtypes: float64(3), int64(2), object(11)
# memory usage: 25.6+ MB

# %% [markdown]
# ### Let’s create some useful variables.
# - Create dummy variables to indicate hit or miss of current shot and previous shot.

# %%
Shotlog['current_shot_hit'] = np.where(Shotlog['current_shot_outcome']=="SCORED", 1, 0)
Shotlog.head()
# Out:
#   team_previous_shot player_position home_game  location_x  \
# 0                NaN              SF       Yes        97.0
# 1             MISSED               C       Yes        52.0
# 2             SCORED              SG       Yes       239.0
# 3             SCORED              PG       Yes       102.0
# 4             SCORED              PF       Yes       128.0
#
#   opponent_previous_shot home_team             shot_type  points away_team  \
# 0                 SCORED       ATL      Pullup Jump Shot       2       WAS
# 1                 SCORED       ATL         Tip Dunk Shot       2       WAS
# 2                 MISSED       ATL             Jump Shot       2       WAS
# 3                 SCORED       ATL      Pullup Jump Shot       2       WAS
# 4                 MISSED       ATL  Turnaround Jump Shot       2       WAS
#
#    location_y  time        date     shoot_player  time_from_last_shot  \
# 0       405.0  1:09  10/27/2016    Kent Bazemore                  NaN
# 1       250.0  1:11  10/27/2016    Dwight Howard                  2.0
# 2       223.0  1:41  10/27/2016      Kyle Korver                 30.0
# 3       385.0  2:16  10/27/2016  Dennis Schroder                 35.0
# 4       265.0  2:40  10/27/2016     Paul Millsap                 24.0
#
#    quarter current_shot_outcome  current_shot_hit
# 0        1               MISSED                 0
# 1        1               SCORED                 1
# 2        1               SCORED                 1
# 3        1               SCORED                 1
# 4        1               MISSED                 0

# %% [markdown]
# - Make sure the variable "date" is stored as a date type variable.

# %%
import datetime as dt
Shotlog['date']=pd.to_datetime(Shotlog['date'])

# %% [markdown]
# - Convert the variable "time" to be datetime type variable
#  1. We will first add the hour (00) to the time variable since the time variable will be stored in the format 'HH:MM:SS';
#  2. We will use "to_timedelta" to work with variable with only time information.

# %%
Shotlog['time'] = pd.to_timedelta('00:'+ Shotlog['time'])
Shotlog['time'].describe()
# Out:
# count                    210072
# mean     0 days 00:06:08.994773
# std      0 days 00:03:28.346263
# min             0 days 00:00:00
# 25%             0 days 00:03:08
# 50%             0 days 00:06:06
# 75%             0 days 00:09:10
# max             0 days 00:12:00
# Name: time, dtype: object

# %% [markdown]
# - Create lagged variable to indicate the result of the previous shot by the same player in the same game.
#  1. We will first sort the shot outcome by the quarter and time in the game;
#  2. We will group the data by player and game (date) and use the "shift" command to create a lag variable.

# %%
Shotlog['lag_shot_hit']=Shotlog.sort_values(by=['quarter','time'], ascending=[True, True]).groupby(['shoot_player','date'])['current_shot_hit'].shift(1)
Shotlog.head()
# Out:
#   team_previous_shot player_position home_game  location_x  \
# 0                NaN              SF       Yes        97.0
# 1             MISSED               C       Yes        52.0
# 2             SCORED              SG       Yes       239.0
# 3             SCORED              PG       Yes       102.0
# 4             SCORED              PF       Yes       128.0
#
#   opponent_previous_shot home_team             shot_type  points away_team  \
# 0                 SCORED       ATL      Pullup Jump Shot       2       WAS
# 1                 SCORED       ATL         Tip Dunk Shot       2       WAS
# 2                 MISSED       ATL             Jump Shot       2       WAS
# 3                 SCORED       ATL      Pullup Jump Shot       2       WAS
# 4                 MISSED       ATL  Turnaround Jump Shot       2       WAS
#
#    location_y     time       date     shoot_player  time_from_last_shot  \
# 0       405.0 00:01:09 2016-10-27    Kent Bazemore                  NaN
# 1       250.0 00:01:11 2016-10-27    Dwight Howard                  2.0
# 2       223.0 00:01:41 2016-10-27      Kyle Korver                 30.0
# 3       385.0 00:02:16 2016-10-27  Dennis Schroder                 35.0
# 4       265.0 00:02:40 2016-10-27     Paul Millsap                 24.0
#
#    quarter current_shot_outcome  current_shot_hit  lag_shot_hit
# 0        1               MISSED                 0           NaN
# 1        1               SCORED                 1           NaN
# 2        1               SCORED                 1           NaN
# 3        1               SCORED                 1           NaN
# 4        1               MISSED                 0           NaN

# %% [markdown]
# #### We can sort the shot log data by player, game(date),  quarter, and time of the shot.

# %%
Shotlog.sort_values(by=['shoot_player', 'date', 'quarter', 'time'], ascending=[True, True, True, True])
# Out:
#       team_previous_shot player_position home_game  location_x  \
# 42660             MISSED               C        No       210.0
# 42661             SCORED               C        No       308.0
# 42664             MISSED               C        No       167.0
# 42667             SCORED               C        No       131.0
# 42668             MISSED               C        No        72.0
# 43139             SCORED               C       Yes       882.0
# 43228             MISSED               C        No        84.0
# 43557             SCORED               C       Yes       873.0
# 43560             MISSED               C       Yes       760.0
# 43716             SCORED               C       Yes       691.0
# 43721             SCORED               C       Yes       882.0
# 43963             MISSED               C       Yes       666.0
# 43964             SCORED               C       Yes       694.0
# 44087             SCORED               C        No       288.0
# 44127             MISSED               C       Yes       136.0
# 44135             SCORED               C       Yes        54.0
# 44172            BLOCKED               C       Yes       886.0
# 44194             SCORED               C       Yes       871.0
# 44210             SCORED               C        No       661.0
# 44212             SCORED               C        No       888.0
# 44214             SCORED               C        No       650.0
# 44774             MISSED               C        No        52.0
# 48239             MISSED               C        No       675.0
# 48268             SCORED               C        No       244.0
# 48274             SCORED               C        No       241.0
# 48275             MISSED               C        No        52.0
# 48283             MISSED               C        No        67.0
# 48290             MISSED               C        No        94.0
# 48436             SCORED               C       Yes       720.0
# 48454             MISSED               C       Yes       827.0
# ...                  ...             ...       ...         ...
# 69686            BLOCKED               C        No        87.0
# 69687             MISSED               C        No        50.0
# 69691             SCORED               C        No        51.0
# 69729             SCORED               C       Yes        67.0
# 69732             MISSED               C       Yes        77.0
# 69780             SCORED               C       Yes       807.0
# 69826             MISSED               C       Yes       107.0
# 69832             MISSED               C       Yes        64.0
# 69835             MISSED               C       Yes       131.0
# 69839             MISSED               C       Yes        79.0
# 69873             MISSED               C       Yes       768.0
# 69916             MISSED               C       Yes        67.0
# 69951             SCORED               C       Yes       861.0
# 69957             MISSED               C       Yes       819.0
# 69958             MISSED               C       Yes       888.0
# 69963             SCORED               C       Yes       876.0
# 69994                NaN               C        No       740.0
# 69996             SCORED               C        No       724.0
# 70031             MISSED               C        No       873.0
# 70051             SCORED               C        No       211.0
# 70086             MISSED               C       Yes        64.0
# 70100             MISSED               C       Yes        67.0
# 70182             MISSED               C       Yes        64.0
# 70187            BLOCKED               C       Yes        59.0
# 70216             MISSED               C       Yes       118.0
# 70218             SCORED               C       Yes        58.0
# 70255            BLOCKED               C       Yes       866.0
# 70264             SCORED               C       Yes       239.0
# 70270             MISSED               C       Yes        52.0
# 70329             MISSED               C       Yes       241.0
#
#       opponent_previous_shot home_team              shot_type  points  \
# 42660                 SCORED       GSW              Jump Shot       2
# 42661                 SCORED       GSW              Jump Shot       3
# 42664                 SCORED       GSW              Jump Shot       2
# 42667                 MISSED       GSW              Jump Shot       2
# 42668                 MISSED       GSW         Tip Layup Shot       2
# 43139                 SCORED       DAL  Running Reverse Layup       2
# 43228                 SCORED       CLE   Turnaround Jump Shot       2
# 43557                BLOCKED       DAL          Driving Layup       2
# 43560                 MISSED       DAL              Jump Shot       2
# 43716                 SCORED       DAL              Jump Shot       2
# 43721                 SCORED       DAL                  Layup       2
# 43963                 SCORED       DAL              Jump Shot       3
# 43964                 SCORED       DAL              Jump Shot       2
# 44087                 MISSED       UTA              Jump Shot       3
# 44127                 MISSED       DAL   Turnaround Hook Shot       2
# 44135                 MISSED       DAL              Jump Shot       3
# 44172                 MISSED       DAL                  Layup       2
# 44194                 SCORED       DAL              Jump Shot       2
# 44210                 SCORED       DEN              Jump Shot       3
# 44212                 MISSED       DEN         Alley Oop Dunk       2
# 44214                 MISSED       DEN              Jump Shot       3
# 44774                BLOCKED       GSW           Running Dunk       2
# 48239                 SCORED       SAC              Jump Shot       3
# 48268                 MISSED       SAC              Jump Shot       3
# 48274                 SCORED       SAC              Jump Shot       2
# 48275                 MISSED       SAC         Alley Oop Dunk       2
# 48283                 SCORED       SAC              Jump Shot       3
# 48290                 SCORED       SAC       Pullup Jump Shot       2
# 48436                 SCORED       DAL              Jump Shot       2
# 48454                 SCORED       DAL              Jump Shot       2
# ...                      ...       ...                    ...     ...
# 69686                 MISSED       SAS         Jump Bank Shot       2
# 69687                 MISSED       SAS      Finger Roll Layup       2
# 69691                 SCORED       SAS          Reverse Layup       2
# 69729                 SCORED       GSW                  Layup       2
# 69732                 MISSED       GSW                  Layup       2
# 69780                 SCORED       GSW   Turnaround Hook Shot       2
# 69826                 SCORED       GSW              Jump Shot       2
# 69832                 SCORED       GSW          Running Layup       2
# 69835                 MISSED       GSW              Jump Shot       2
# 69839                 SCORED       GSW                  Layup       2
# 69873                 SCORED       GSW              Jump Shot       2
# 69916                 SCORED       GSW                  Layup       2
# 69951                 SCORED       GSW                  Layup       2
# 69957                 SCORED       GSW   Turnaround Hook Shot       2
# 69958                 SCORED       GSW                   Dunk       2
# 69963                 MISSED       GSW          Running Layup       2
# 69994                    NaN       PHX              Jump Shot       2
# 69996                 MISSED       PHX              Jump Shot       2
# 70031                 SCORED       PHX   Turnaround Bank Shot       2
# 70051                 MISSED       PHX              Jump Shot       2
# 70086                 MISSED       GSW     Cutting Layup Shot       2
# 70100                 MISSED       GSW              Jump Shot       2
# 70182                 SCORED       GSW  Driving Reverse Layup       2
# 70187                 SCORED       GSW  Driving Reverse Layup       2
# 70216                 MISSED       GSW         Jump Bank Shot       2
# 70218                 MISSED       GSW                  Layup       2
# 70255                 SCORED       GSW                  Layup       2
# 70264                 SCORED       GSW              Jump Shot       2
# 70270                 SCORED       GSW         Tip Layup Shot       2
# 70329                 MISSED       GSW              Jump Shot       3
#
#       away_team  location_y     time       date   shoot_player  \
# 42660       DAL       269.0 00:07:23 2016-11-09   A.J. Hammons
# 42661       DAL       202.0 00:07:56 2016-11-09   A.J. Hammons
# 42664       DAL       318.0 00:09:26 2016-11-09   A.J. Hammons
# 42667       DAL       337.0 00:11:46 2016-11-09   A.J. Hammons
# 42668       DAL       248.0 00:11:47 2016-11-09   A.J. Hammons
# 43139       LAC       264.0 00:10:24 2016-11-23   A.J. Hammons
# 43228       DAL       112.0 00:08:02 2016-11-25   A.J. Hammons
# 43557       CHI       248.0 00:10:05 2016-12-03   A.J. Hammons
# 70100       NOP       405.0 00:06:25 2017-04-08  Zaza Pachulia
# 70182       UTA       259.0 00:01:50 2017-04-10  Zaza Pachulia
# 70187       UTA       236.0 00:05:45 2017-04-10  Zaza Pachulia
# 70216       UTA       133.0 00:09:53 2017-04-10  Zaza Pachulia
# 70218       UTA       241.0 00:11:08 2017-04-10  Zaza Pachulia
# 70255       UTA       252.0 00:10:33 2017-04-10  Zaza Pachulia
# 70264       LAL       272.0 00:01:41 2017-04-12  Zaza Pachulia
# 70270       LAL       251.0 00:04:32 2017-04-12  Zaza Pachulia
# 70329       LAL       200.0 00:12:00 2017-04-12  Zaza Pachulia
#
#        time_from_last_shot  quarter current_shot_outcome  current_shot_hit  \
# 42660                 43.0        4               SCORED                 1
# 42661                 33.0        4               SCORED                 1
# 42664                 51.0        4               MISSED                 0
# 42667                 62.0        4               MISSED                 0
# 42668                  1.0        4               SCORED                 1
# 43139                 22.0        4               MISSED                 0
# 43228                 33.0        4              BLOCKED                 0
# 43557                 40.0        4              BLOCKED                 0
# 43560                 14.0        4               SCORED                 1
# 43716                 65.0        4               MISSED                 0
# 43721                 41.0        4              BLOCKED                 0
# 43963                 30.0        4               SCORED                 1
# 43964                 25.0        4               MISSED                 0
# 44087                 36.0        3               SCORED                 1
# 44127                 32.0        1               MISSED                 0
# 44135                 34.0        1               MISSED                 0
# 44172                 11.0        3              BLOCKED                 0
# 44194                 34.0        4               MISSED                 0
# 44210                 26.0        1               SCORED                 1
# 44212                 34.0        1               SCORED                 1
# 44214                 21.0        1               MISSED                 0
# 44774                  8.0        4               SCORED                 1
# 48239                 25.0        2               MISSED                 0
# 48268                 33.0        3               SCORED                 1
# 48274                 31.0        3               MISSED                 0
# 48275                 19.0        3               SCORED                 1
# 48283                 41.0        4               MISSED                 0
# 48290                 71.0        4               SCORED                 1
# 48436                 34.0        3               MISSED                 0
# 48454                 31.0        4               MISSED                 0
# ...                    ...      ...                  ...               ...
# 69686                  5.0        3               MISSED                 0
# 69687                 25.0        3               SCORED                 1
# 69691                 76.0        3               MISSED                 0
# 69729                 44.0        1               SCORED                 1
# 69732                 61.0        1               MISSED                 0
# 69780                 41.0        3               MISSED                 0
# 69826                 17.0        1               MISSED                 0
# 69832                 32.0        1               SCORED                 1
# 69835                 23.0        1               SCORED                 1
# 69839                 25.0        1              BLOCKED                 0
# 69873                 28.0        3               SCORED                 1
# 69916                 36.0        1               SCORED                 1
# 69951                  NaN        3              BLOCKED                 0
# 69957                 12.0        3               MISSED                 0
# 69958                 32.0        3               SCORED                 1
# 69963                 24.0        3               SCORED                 1
# 69994                  NaN        1               MISSED                 0
# 69996                 28.0        1               SCORED                 1
# 70031                  7.0        2               SCORED                 1
# 70051                 32.0        3               MISSED                 0
# 70086                  8.0        1               SCORED                 1
# 70100                 32.0        1               MISSED                 0
# 70182                 17.0        1               SCORED                 1
# 70187                 27.0        1               SCORED                 1
# 70216                 37.0        2               MISSED                 0
# 70218                 47.0        2               SCORED                 1
# 70255                  5.0        4               MISSED                 0
# 70264                 29.0        1               SCORED                 1
# 70270                  1.0        1               SCORED                 1
# 70329                 25.0        3               MISSED                 0
#
#        lag_shot_hit
# 42660           NaN
# 42661           1.0
# 42664           1.0
# 42667           0.0
# 42668           0.0
# 43139           NaN
# 43228           NaN
# 43557           NaN
# 43560           0.0
# 43716           NaN
# 43721           0.0
# 43963           NaN
# 43964           1.0
# 44087           NaN
# 44127           NaN
# 44135           0.0
# 44172           0.0
# 44194           0.0
# 44210           NaN
# 44212           1.0
# 44214           1.0
# 44774           NaN
# 48239           NaN
# 48268           0.0
# 48274           1.0
# 48275           0.0
# 48283           1.0
# 48290           0.0
# 48436           NaN
# 48454           0.0
# ...             ...
# 69686           0.0
# 69687           0.0
# 69691           1.0
# 69729           NaN
# 69732           1.0
# 69780           0.0
# 69826           NaN
# 69832           0.0
# 69835           1.0
# 69839           1.0
# 69873           0.0
# 69916           NaN
# 69951           1.0
# 69957           0.0
# 69958           0.0
# 69963           1.0
# 69994           NaN
# 69996           0.0
# 70031           1.0
# 70051           1.0
# 70086           NaN
# 70100           1.0
# 70182           NaN
# 70187           1.0
# 70216           1.0
# 70218           0.0
# 70255           1.0
# 70264           NaN
# 70270           1.0
# 70329           1.0
#
# [210072 rows x 18 columns]

# %% [markdown]
# _Notice that for the first shots of the game by the given players, the lagged outcome variable will have missing value._
#
# #### Let's create a dataframe for average success rate of players over the season.
#
# Since the "current_shot_hit" variable is a dummy variable (=1 if hit, =0 if miss), the average of this variable would indicate the success rate of the player over the season.

# %%
Player_Stats=Shotlog.groupby(['shoot_player'])['current_shot_hit'].mean()
Player_Stats=Player_Stats.reset_index()
Player_Stats.head()
# Out:
#      shoot_player  current_shot_hit
# 0    A.J. Hammons          0.404762
# 1    Aaron Brooks          0.403333
# 2    Aaron Gordon          0.454861
# 3  Aaron Harrison          0.000000
# 4   Adreian Payne          0.425926

# %% [markdown]
# - Let's rename the "current_shot_hit" variable in the newly created date frame as "average_hit".

# %%
Player_Stats.rename(columns={'current_shot_hit':'average_hit'}, inplace=True)

# %% [markdown]
# #### We will use the player statistics to analyze the hot hand. So we will merge average player statistics dataframe back to the shot log dataframe.

# %%
Shotlog=pd.merge(Shotlog, Player_Stats, on=['shoot_player'])
Shotlog.head()
# Out:
#   team_previous_shot player_position home_game  location_x  \
# 0                NaN              SF       Yes        97.0
# 1             MISSED              SF       Yes       279.0
# 2             MISSED              SF       Yes        58.0
# 3             SCORED              SF       Yes       868.0
# 4             SCORED              SF       Yes       691.0
#
#   opponent_previous_shot home_team           shot_type  points away_team  \
# 0                 SCORED       ATL    Pullup Jump Shot       2       WAS
# 1                 SCORED       ATL           Jump Shot       3       WAS
# 2                 SCORED       ATL  Cutting Layup Shot       2       WAS
# 3                 SCORED       ATL           Jump Shot       3       WAS
# 4                 MISSED       ATL    Pullup Jump Shot       3       WAS
#
#    location_y     time       date   shoot_player  time_from_last_shot  \
# 0       405.0 00:01:09 2016-10-27  Kent Bazemore                  NaN
# 1       130.0 00:03:11 2016-10-27  Kent Bazemore                  4.0
# 2       275.0 00:09:53 2016-10-27  Kent Bazemore                 30.0
# 3       475.0 00:01:02 2016-10-27  Kent Bazemore                 47.0
# 4       100.0 00:04:50 2016-10-27  Kent Bazemore                 39.0
#
#    quarter current_shot_outcome  current_shot_hit  lag_shot_hit  average_hit
# 0        1               MISSED                 0           NaN     0.408587
# 1        1               MISSED                 0           0.0     0.408587
# 2        2               MISSED                 0           0.0     0.408587
# 3        3               MISSED                 0           0.0     0.408587
# 4        3               SCORED                 1           0.0     0.408587

# %% [markdown]
# - Create a variable to indicate the total number of shots recorded in the dataset for each player.

# %%
Player_Shots=Shotlog.groupby(['shoot_player']).size().reset_index(name='shot_count')

# %%
Player_Shots.sort_values(by=['shot_count'], ascending=[False]).head()
# Out:
#           shoot_player  shot_count
# 402  Russell Westbrook        1940
# 25      Andrew Wiggins        1568
# 106      DeMar DeRozan        1545
# 193       James Harden        1532
# 28       Anthony Davis        1525

# %% [markdown]
# We should also note that players have different number of shots in each individual game. We will need to treat the data differently for a player who had only two shots in a game compared to those who had attempted 30 in a game.
#
# - Create a variable to indicate the number of shots in each game for by each player.

# %%
Player_Game=Shotlog.groupby(['shoot_player','date']).size().reset_index(name='shot_per_game')
Player_Game.head()
# Out:
#    shoot_player       date  shot_per_game
# 0  A.J. Hammons 2016-11-09              5
# 1  A.J. Hammons 2016-11-23              1
# 2  A.J. Hammons 2016-11-25              1
# 3  A.J. Hammons 2016-12-03              2
# 4  A.J. Hammons 2016-12-07              2

# %% [markdown]
# #### We will merge the shot count data frames back to the shot log dataframe.

# %%
Shotlog=pd.merge(Shotlog, Player_Shots, on=['shoot_player'])
Shotlog=pd.merge(Shotlog, Player_Game, on=['shoot_player','date'])
display(Shotlog)
# Out:
#        team_previous_shot player_position home_game  location_x  \
# 0                     NaN              SF       Yes        97.0
# 1                  MISSED              SF       Yes       279.0
# 2                  MISSED              SF       Yes        58.0
# 3                  SCORED              SF       Yes       868.0
# 4                  SCORED              SF       Yes       691.0
# 5                  MISSED              SF       Yes       691.0
# 6                  MISSED              SF       Yes       679.0
# 7                  MISSED              SF        No       760.0
# 8                  SCORED              SF        No       920.0
# 9                  MISSED              SF        No         NaN
# 10                 SCORED              SF        No       890.0
# 11                 MISSED              SF        No       899.0
# 12                 MISSED              SF        No       838.0
# 13                 SCORED              SF        No       886.0
# 14                 SCORED              SF        No        77.0
# 15                 SCORED              SF        No        51.0
# 16                 SCORED              SF        No        84.0
# 17                 MISSED              SF        No       107.0
# 18                 SCORED              SF       Yes        54.0
# 19                 MISSED              SF       Yes        50.0
# 20                 SCORED              SF       Yes       701.0
# 21                BLOCKED              SF       Yes       889.0
# 22                 MISSED              SF       Yes       670.0
# 23                 SCORED              SF       Yes       652.0
# 24                 MISSED              SF       Yes       858.0
# 25                 SCORED              SF       Yes       863.0
# 26                 MISSED              SF       Yes       686.0
# 27                 SCORED              SF       Yes        54.0
# 28                 MISSED              SF       Yes        53.0
# 29                 SCORED              SF       Yes        58.0
# ...                   ...             ...       ...         ...
# 210042             MISSED               C        No       873.0
# 210043             MISSED               C        No       858.0
# 210044             SCORED               C        No       843.0
# 210045             MISSED               C        No       882.0
# 210046             MISSED               C        No        77.0
# 210047             MISSED               C        No        67.0
# 210048             MISSED               C        No       882.0
# 210049             SCORED               C        No       882.0
# 210050             MISSED               C        No       853.0
# 210051             MISSED               C        No        52.0
# 210052             SCORED               C        No        53.0
# 210053             MISSED               C        No        51.0
# 210054             SCORED               C        No        64.0
# 210055             MISSED               C        No        52.0
# 210056             MISSED               C        No        84.0
# 210057             MISSED               C        No       138.0
# 210058             SCORED               C       Yes       881.0
# 210059             MISSED               C       Yes       882.0
# 210060             MISSED               C        No       888.0
# 210061             SCORED               C        No       876.0
# 210062             MISSED               C        No        50.0
# 210063             SCORED               C       Yes        53.0
# 210064             SCORED               C       Yes       103.0
# 210065             SCORED               C       Yes       866.0
# 210066             SCORED               C       Yes       895.0
# 210067             SCORED               C        No       878.0
# 210068             SCORED               C        No       878.0
# 210069             MISSED               C        No       863.0
# 210070             SCORED               C        No        58.0
# 210071             MISSED               C        No        52.0
#
#        opponent_previous_shot home_team             shot_type  points  \
# 0                      SCORED       ATL      Pullup Jump Shot       2
# 1                      SCORED       ATL             Jump Shot       3
# 2                      SCORED       ATL    Cutting Layup Shot       2
# 3                      SCORED       ATL             Jump Shot       3
# 4                      MISSED       ATL      Pullup Jump Shot       3
# 5                      MISSED       ATL      Pullup Jump Shot       2
# 6                      MISSED       ATL   Step Back Jump Shot       3
# 7                      SCORED       PHI             Jump Shot       2
# 8                      MISSED       PHI             Jump Shot       3
# 9                      MISSED       PHI             Jump Shot       3
# 10                     MISSED       PHI             Jump Shot       2
# 11                     MISSED       PHI             Jump Shot       2
# 12                     MISSED       PHI             Jump Shot       2
# 13                     SCORED       PHI         Reverse Layup       2
# 14                     MISSED       PHI             Jump Shot       2
# 15                    BLOCKED       PHI    Cutting Layup Shot       2
# 16                     SCORED       PHI      Pullup Jump Shot       2
# 17                     MISSED       PHI             Jump Shot       2
# 18                     MISSED       ATL         Running Layup       2
# 19                     MISSED       ATL    Cutting Layup Shot       2
# 20                     MISSED       ATL     Running Jump Shot       3
# 21                     SCORED       ATL    Cutting Layup Shot       2
# 22                     MISSED       ATL      Pullup Jump Shot       3
# 23                     MISSED       ATL      Pullup Jump Shot       3
# 24                     SCORED       ATL      Pullup Jump Shot       2
# 25                     MISSED       ATL             Jump Shot       3
# 26                     SCORED       ATL             Jump Shot       3
# 27                        NaN       ATL             Jump Shot       3
# 28                     SCORED       ATL       Alley Oop Layup       2
# 29                     SCORED       ATL         Driving Layup       2
# ...                       ...       ...                   ...     ...
# 210042                 SCORED       LAC             Jump Shot       2
# 210043                 SCORED       LAC             Hook Shot       2
# 210044                 MISSED       LAC             Hook Shot       2
# 210045                 MISSED       LAC         Running Layup       2
# 210046                 SCORED       LAC        Tip Layup Shot       2
# 210047                 MISSED       LAC         Running Layup       2
# 210048                 SCORED       UTA             Hook Shot       2
# 210049                 MISSED       UTA         Driving Layup       2
# 210064           1.0     0.590909         110              4
# 210065           1.0     0.590909         110              4
# 210066           1.0     0.590909         110              4
# 210067           NaN     0.590909         110              5
# 210068           0.0     0.590909         110              5
# 210069           1.0     0.590909         110              5
# 210070           0.0     0.590909         110              5
# 210071           1.0     0.590909         110              5
#
# [210072 rows x 21 columns]

# %% [markdown]
# #### We will sort the data again after merging.

# %%
Shotlog.sort_values(by=['shoot_player', 'date', 'quarter', 'time'], ascending=[True, True, True, True])
# Out:
#       team_previous_shot player_position home_game  location_x  \
# 50484             MISSED               C        No       210.0
# 50485             SCORED               C        No       308.0
# 50486             MISSED               C        No       167.0
# 50487             SCORED               C        No       131.0
# 50488             MISSED               C        No        72.0
# 50489             SCORED               C       Yes       882.0
# 50490             MISSED               C        No        84.0
# 50491             SCORED               C       Yes       873.0
# 50492             MISSED               C       Yes       760.0
# 50493             SCORED               C       Yes       691.0
# 50494             SCORED               C       Yes       882.0
# 50495             MISSED               C       Yes       666.0
# 50496             SCORED               C       Yes       694.0
# 50497             SCORED               C        No       288.0
# 50498             MISSED               C       Yes       136.0
# 50499             SCORED               C       Yes        54.0
# 50500            BLOCKED               C       Yes       886.0
# 50501             SCORED               C       Yes       871.0
# 50502             SCORED               C        No       661.0
# 50503             SCORED               C        No       888.0
# 50504             SCORED               C        No       650.0
# 50505             MISSED               C        No        52.0
# 50506             MISSED               C        No       675.0
# 50507             SCORED               C        No       244.0
# 50508             SCORED               C        No       241.0
# 50509             MISSED               C        No        52.0
# 50510             MISSED               C        No        67.0
# 50511             MISSED               C        No        94.0
# 50512             SCORED               C       Yes       720.0
# 50513             MISSED               C       Yes       827.0
# ...                  ...             ...       ...         ...
# 72756            BLOCKED               C        No        87.0
# 72757             MISSED               C        No        50.0
# 72758             SCORED               C        No        51.0
# 72759             SCORED               C       Yes        67.0
# 72760             MISSED               C       Yes        77.0
# 72761             SCORED               C       Yes       807.0
# 72762             MISSED               C       Yes       107.0
# 72763             MISSED               C       Yes        64.0
# 72764             MISSED               C       Yes       131.0
# 72765             MISSED               C       Yes        79.0
# 72766             MISSED               C       Yes       768.0
# 72767             MISSED               C       Yes        67.0
# 72768             SCORED               C       Yes       861.0
# 72769             MISSED               C       Yes       819.0
# 72770             MISSED               C       Yes       888.0
# 72771             SCORED               C       Yes       876.0
# 72772                NaN               C        No       740.0
# 72773             SCORED               C        No       724.0
# 72774             MISSED               C        No       873.0
# 72775             SCORED               C        No       211.0
# 72776             MISSED               C       Yes        64.0
# 72777             MISSED               C       Yes        67.0
# 72778             MISSED               C       Yes        64.0
# 72779            BLOCKED               C       Yes        59.0
# 72780             MISSED               C       Yes       118.0
# 72781             SCORED               C       Yes        58.0
# 72782            BLOCKED               C       Yes       866.0
# 72783             SCORED               C       Yes       239.0
# 72784             MISSED               C       Yes        52.0
# 72785             MISSED               C       Yes       241.0
#
#       opponent_previous_shot home_team              shot_type  points  \
# 50484                 SCORED       GSW              Jump Shot       2
# 50485                 SCORED       GSW              Jump Shot       3
# 50486                 SCORED       GSW              Jump Shot       2
# 50487                 MISSED       GSW              Jump Shot       2
# 50488                 MISSED       GSW         Tip Layup Shot       2
# 50489                 SCORED       DAL  Running Reverse Layup       2
# 50490                 SCORED       CLE   Turnaround Jump Shot       2
# 50491                BLOCKED       DAL          Driving Layup       2
# 50492                 MISSED       DAL              Jump Shot       2
# 50493                 SCORED       DAL              Jump Shot       2
# 50494                 SCORED       DAL                  Layup       2
# 50495                 SCORED       DAL              Jump Shot       3
# 50496                 SCORED       DAL              Jump Shot       2
# 50497                 MISSED       UTA              Jump Shot       3
# 50498                 MISSED       DAL   Turnaround Hook Shot       2
# 50499                 MISSED       DAL              Jump Shot       3
# 50500                 MISSED       DAL                  Layup       2
# 50501                 SCORED       DAL              Jump Shot       2
# 50502                 SCORED       DEN              Jump Shot       3
# 50503                 MISSED       DEN         Alley Oop Dunk       2
# 50504                 MISSED       DEN              Jump Shot       3
# 50505                BLOCKED       GSW           Running Dunk       2
# 50506                 SCORED       SAC              Jump Shot       3
# 50507                 MISSED       SAC              Jump Shot       3
# 50508                 SCORED       SAC              Jump Shot       2
# 50509                 MISSED       SAC         Alley Oop Dunk       2
# 50510                 SCORED       SAC              Jump Shot       3
# 50511                 SCORED       SAC       Pullup Jump Shot       2
# 50512                 SCORED       DAL              Jump Shot       2
# 50513                 SCORED       DAL              Jump Shot       2
# ...                      ...       ...                    ...     ...
# 72756                 MISSED       SAS         Jump Bank Shot       2
# 72757                 MISSED       SAS      Finger Roll Layup       2
# 72758                 SCORED       SAS          Reverse Layup       2
# 72759                 SCORED       GSW                  Layup       2
# 72760                 MISSED       GSW                  Layup       2
# 72761                 SCORED       GSW   Turnaround Hook Shot       2
# 72762                 SCORED       GSW              Jump Shot       2
# 72763                 SCORED       GSW          Running Layup       2
# 72764                 MISSED       GSW              Jump Shot       2
# 72765                 SCORED       GSW                  Layup       2
# 72766                 SCORED       GSW              Jump Shot       2
# 72767                 SCORED       GSW                  Layup       2
# 72768                 SCORED       GSW                  Layup       2
# 72769                 SCORED       GSW   Turnaround Hook Shot       2
# 72770                 SCORED       GSW                   Dunk       2
# 72771                 MISSED       GSW          Running Layup       2
# 72772                    NaN       PHX              Jump Shot       2
# 72773                 MISSED       PHX              Jump Shot       2
# 72774                 SCORED       PHX   Turnaround Bank Shot       2
# 72775                 MISSED       PHX              Jump Shot       2
# 72776                 MISSED       GSW     Cutting Layup Shot       2
# 72777                 MISSED       GSW              Jump Shot       2
# 72778                 SCORED       GSW  Driving Reverse Layup       2
# 72779                 SCORED       GSW  Driving Reverse Layup       2
# 72780                 MISSED       GSW         Jump Bank Shot       2
# 72781                 MISSED       GSW                  Layup       2
# 72782                 SCORED       GSW                  Layup       2
# 72783                 SCORED       GSW              Jump Shot       2
# 72784                 SCORED       GSW         Tip Layup Shot       2
# 72785                 MISSED       GSW              Jump Shot       3
#
#       away_team  location_y  ...       date   shoot_player  \
# 50484       DAL       269.0  ... 2016-11-09   A.J. Hammons
# 50485       DAL       202.0  ... 2016-11-09   A.J. Hammons
# 50484           NaN     0.404762          42              5
# 50485           1.0     0.404762          42              5
# 50486           1.0     0.404762          42              5
# 50487           0.0     0.404762          42              5
# 50488           0.0     0.404762          42              5
# 50489           NaN     0.404762          42              1
# 50490           NaN     0.404762          42              1
# 50491           NaN     0.404762          42              2
# 50492           0.0     0.404762          42              2
# 50493           NaN     0.404762          42              2
# 50494           0.0     0.404762          42              2
# 50495           NaN     0.404762          42              2
# 50496           1.0     0.404762          42              2
# 50497           NaN     0.404762          42              1
# 50498           NaN     0.404762          42              4
# 50499           0.0     0.404762          42              4
# 50500           0.0     0.404762          42              4
# 50501           0.0     0.404762          42              4
# 50502           NaN     0.404762          42              3
# 50503           1.0     0.404762          42              3
# 50504           1.0     0.404762          42              3
# 50505           NaN     0.404762          42              1
# 50506           NaN     0.404762          42              6
# 50507           0.0     0.404762          42              6
# 50508           1.0     0.404762          42              6
# 50509           0.0     0.404762          42              6
# 50510           1.0     0.404762          42              6
# 50511           0.0     0.404762          42              6
# 50512           NaN     0.404762          42              2
# 50513           0.0     0.404762          42              2
# ...             ...          ...         ...            ...
# 72756           0.0     0.535948         306              7
# 72757           0.0     0.535948         306              7
# 72758           1.0     0.535948         306              7
# 72759           NaN     0.535948         306              3
# 72760           1.0     0.535948         306              3
# 72761           0.0     0.535948         306              3
# 72762           NaN     0.535948         306              5
# 72763           0.0     0.535948         306              5
# 72764           1.0     0.535948         306              5
# 72765           1.0     0.535948         306              5
# 72766           0.0     0.535948         306              5
# 72767           NaN     0.535948         306              5
# 72768           1.0     0.535948         306              5
# 72769           0.0     0.535948         306              5
# 72770           0.0     0.535948         306              5
# 72771           1.0     0.535948         306              5
# 72772           NaN     0.535948         306              4
# 72773           0.0     0.535948         306              4
# 72774           1.0     0.535948         306              4
# 72775           1.0     0.535948         306              4
# 72776           NaN     0.535948         306              2
# 72777           1.0     0.535948         306              2
# 72778           NaN     0.535948         306              5
# 72779           1.0     0.535948         306              5
# 72780           1.0     0.535948         306              5
# 72781           0.0     0.535948         306              5
# 72782           1.0     0.535948         306              5
# 72783           NaN     0.535948         306              3
# 72784           1.0     0.535948         306              3
# 72785           1.0     0.535948         306              3
#
# [210072 rows x 21 columns]

# %% [markdown]
# #### We will treat the "points" and "quarter" variables as objects.

# %%
Shotlog['points'] = Shotlog['points'].astype(object)
Shotlog['quarter'] = Shotlog['quarter'].astype(object)

# %% [markdown]
# #### Missing values
# - Drop observations with missing value in lagged variable.

# %%
Shotlog=Shotlog[pd.notnull(Shotlog["lag_shot_hit"])]

# %% [markdown]
# #### Let's take a quick look at the number of variables and the number of observations in our clean dataframe.

# %%
Shotlog.shape
# Out:
# (185052, 21)

# %% [markdown]
# ### Save our updated data

# %%
Shotlog.to_csv("../../Data/Week 6/Shotlog1.csv", index=False)
Player_Stats.to_csv("../../Data/Week 6/Player_Stats1.csv", index=False)
Player_Shots.to_csv("../../Data/Week 6/Player_Shots1.csv", index=False)
Player_Game.to_csv("../../Data/Week 6/Player_Game1.csv", index=False)
